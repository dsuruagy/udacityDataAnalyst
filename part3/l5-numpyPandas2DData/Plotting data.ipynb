# %% [markdown]
# # matplotlib plot()
#
# [Documentation](http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.plot)
#
# [Examples](http://www.python-course.eu/matplotlib.php)

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
#plt.plot([-1, -4.5, 16, 23])
#plt.plot([-1, -4.5, 16, 23], "ob")
plt.plot([-1, -4.5, 16, 23], "-.b")
plt.show()

# %%
import matplotlib.pyplot as plt
# our X values:
days = list(range(0, 22, 3))
print(days)
# our Y values:
celsius_values = [25.6, 24.1, 26.7, 28.3, 27.5, 30.5, 32.8, 33.1]
plt.plot(days, celsius_values)
plt.xlabel('Day')
plt.ylabel('Degrees Celsius')
plt.show()
# Out:
# [0, 3, 6, 9, 12, 15, 18, 21]

# %%
import matplotlib.pyplot as plt
days = list(range(1,9))
celsius_min = [19.6, 24.1, 26.7, 28.3, 27.5, 30.5, 32.8, 33.1]
celsius_max = [24.8, 28.9, 31.3, 33.0, 34.9, 35.6, 38.4, 39.2]
plt.xlabel('Day')
plt.ylabel('Degrees Celsius')
plt.plot(days, celsius_min,
         days, celsius_min, "oy",
         days, celsius_max, 
         days, celsius_max, "or")
plt.show()

# %% [markdown]
# # Spines and Ticks

# %%
# the next "inline" statement is only needed,
# if you are working with "ipython notebook"
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
X = np.linspace(-2 * np.pi, 2 * np.pi, 70, endpoint=True)
F1 = np.sin(2* X)
F2 = (2*X**5 + 4*X**4 - 4.8*X**3 + 1.2*X**2 + X + 1)*np.exp(-X**2)
# get the current axes, creating them if necessary:
ax = plt.gca()
# making the top and right spine invisible:
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')
# moving bottom spine up to y=0 position:
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
# moving left spine to the right to position x == 0:
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))
plt.plot(X, F1)
plt.plot(X, F2)
plt.show()

# %% [markdown]
# # Legends

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0, 25, 1000)
y1 = np.sin(x)
y2 = np.cos(x)
plt.plot(x, y1, '-b', label='sine')
plt.plot(x, y2, '-r', label='cosine')
#plt.legend(loc='upper left')
plt.legend(loc='best')
plt.ylim(-1.5, 2.0)
plt.show()

# %% [markdown]
# # Histograms

# %%
# the next "inline" statement is only needed,
# if you are working with "ipython notebook"
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
gaussian_numbers = np.random.normal(size=10000)
plt.hist(gaussian_numbers)
plt.title("Gaussian Histogram")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %%
plt.hist(gaussian_numbers, bins=100)
plt.show()

# %%
plt.hist(gaussian_numbers, bins=100, normed=True)
plt.show()

# %%
plt.hist(gaussian_numbers, 
         bins=100, 
         normed=True, 
         stacked=True, 
         edgecolor="#6A9662",
         color="#DDFFDD")
plt.show()

# %% [markdown]
# # Pandas plot

# %%
import pandas as pd
data = [15, 3, 50, 42.5, 23, 54, 70.9]
s = pd.Series(data, index=range(len(data)))
s.plot()

# %%
fruits = ['apples', 'oranges', 'cherries','pears']
quantities = [25, 43, 38, 23]
fruit_s = pd.Series(quantities, index=fruits)
fruit_s.plot()

# %%
import pandas as pd
cities = {"name": ["London", "Berlin", "Madrid", "Rome", 
                   "Paris", "Vienna", "Bucharest", "Hamburg", 
                   "Budapest", "Warsaw", "Barcelona", 
                   "Munich", "Milan"],
          "population": [8615246, 3562166, 3165235, 2874038,
                         2273305, 1805681, 1803425, 1760433,
                         1754000, 1740119, 1602386, 1493900,
                         1350680],
          "area" : [1572, 891.85, 605.77, 1285, 
                    105.4, 414.6, 228, 755, 
                    525.2, 517, 101.9, 310.4, 
                    181.8]}
city_frame = pd.DataFrame(cities,
                         columns=["population","area"], index=cities["name"])
city_frame["area"] *= 1000 # to make this line visible
city_frame.plot(xticks=range(len(city_frame)), use_index=True, rot=90)

# %%
city_frame = pd.DataFrame(cities,
                          columns=["population", "area"],
                          index=cities["name"])

import matplotlib.pyplot as plt
fig, ax = plt.subplots()
fig.suptitle("City Statistics")
ax.set_ylabel("Population")
ax.set_xlabel("Citites")
ax2 = ax.twinx()
ax2.set_ylabel("Area")
city_frame["population"].plot(ax=ax, 
                              style="b-",
                              use_index=True, 
                              rot=90)
city_frame["area"].plot(ax=ax2, 
                        style="g-",
                        use_index=True, 
                        rot=90)

# %%
import pandas as pd
data = [100, 120, 140, 180, 200, 210, 214]
s = pd.Series(data)
s.plot(kind="bar")

# %%
import pandas as pd
fruits = ['apples', 'pears', 'cherries', 'bananas']
series = pd.Series([20, 30, 40, 10], 
                   index=fruits, 
                   name='Fruits')
series.plot.pie(figsize=(6, 5),explode=[0, 0.10, 0.20, 0.3])
